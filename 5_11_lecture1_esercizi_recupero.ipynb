# %% [markdown]
# # ESERCIZI RECUPERO 5/11/21

# %% [markdown]
# ## ESERCIZIO 1
#
# sintassi: command[flags][argument1][argument2]... le parentesi quadre sono generalmente opzionali. Facciamo alcuni esempi: $ \\ $
#
# * ls -a -l oppure ls -al $ \\ $
# * ls -al mydir dove:
#   * ls $ \implies $ command
#   * al $ \implies $ flag
#   * mydir $ \implies $ argument $ \\ $
#
# gli argomenti possono essere opzionali o obbligatori. $ \\ $
# tutti i comando hanno un codice di ritorno ( $ 0 $ se è ok ) $ \\ $
# tutti i comandi hanno un help $ \implies $ comando ' man command' $ \\ $
#
# Ad esempio: $ \\ $
#
# ls -al il flag 'al' sta a significare ALL, cioè mi fa vedere anche i cosiddetti file nascosti (cioè quelli che iniziano con il punto) che sono dei file di configurazione.

# %% [markdown]
# ## ESERCIZIO 2

# %% [markdown]
# creiamo la cartella esercizi.bash e verifichiamo che sia stata creata con il comando $ \textbf{ls} $

# %% [markdown]
# ![Senza_nome.png](attachment:60d89c33-4370-4106-a8c1-b4298540d3cb.png)

# %% [markdown]
# entriamo nella cartella con $ \textbf{cd esercizi.bash} $ e creiamo con il comando $ \textbf{mkdir lezione_1} $,  $ \textbf{mkdir lezione_2} $ e $ \textbf{mkdir lezione_3} $ altre tre cartelle

# %% [markdown]
# Utilizziamo l'operatore di direzione UNIX " > ". Creiamo il file con  $ \textbf{ls -l > ls_testo.txt} $ . In console non vediamo nulla perchè lo standard output è stato redirezionato nel file. Per vedere il file utilizziamo il comando $ \textbf{cat ls_testo.txt} $

# %% [markdown]
# ![eee.png](attachment:c0bf3e12-e28e-4b44-a3f8-6cab43025dbf.png)

# %% [markdown]
# utilizzo il comando $ \textbf{ vi es.sh} $

# %% [markdown]
# ![es.png](attachment:e7fe1d50-0be4-4c31-8285-c9cb81223a78.png)

# %% [markdown]
# Attraverso il comando   $ \textbf{cd ..} $ torniamo in esercizi.bash e a questo punto creiamo un'altra cartella nominata "dati" con  $ \textbf{mkdir dati} $ e creando anche la bash non interattiva es.sh con il comando  $ \textbf{ vi es.sh} $

# %% [markdown]
# ![Senza_nome4.png](attachment:a5119a0e-685e-47f2-92b1-dd64e0bfe159.png)

# %% [markdown]
# a questo punto nella cartella "dati" creiamo i file "data1.txt" e "data2.txt"  attraverso
# $ \textbf{ls -l > ls_data1.txt} $ e $ \textbf{ls -l > ls_data2.txt} $

# %% [markdown]
# ![senza_nome8.png](attachment:ea688483-854c-4402-aad4-d3918b24234b.png)

# %% [markdown]
# Rinomino il file ls_data2.txt in newdata.txt attraverso il comando $ \textbf{mv ls_data2.txt newdata.txt} $

# %% [markdown]
# ![Senza_nome1.png](attachment:b0f32f46-9b62-4523-98bd-855ae1fc77b6.png)

# %% [markdown]
# creiamo un file es.sh nella cartella lezione_2. $ \\ $
# rendiamo eseguibile attraverso $ \textbf{chmod a +x} $. Analogo passaggio eseguito per il file es.sh nella cartelle lezione_1 e lezione_3.

# %% [markdown]
# ![Senza_nome9.png](attachment:83ae92d4-8115-45ec-b70c-7c8bc07cf7fa.png)

# %% [markdown]
# Togliere i permessi di scrittura ai file.txt attraverso $ \textbf{chmod -r nomefile.txt} $

# %% [markdown]
# ![pippo.png](attachment:e8b2f864-b5bc-4547-bdd0-8f472402c8de.png)

# %% [markdown]
# Processo analogo eseguito per i file presenti nella cartella lezione_3

# %% [markdown]
# ![pippo2.png](attachment:76dd45dd-0f9b-4799-8fe6-7c3d1ee67361.png)

# %% [markdown]
# ## ESERCIZIO 3

# %% [markdown]
# Creo la cartella esercitiazione, nella directory esercizi.bash, con il solito comando $ \textbf{mkdir esercitazione} $ $ \\ $
# entro nella cartella esercitazione $ \textbf{cd esercitazione} $ $ \\ $
# creo il file esercizio.txt con $ \textbf{touch esercizio.txt} $ $ \\ $
# uso il comando echo: $ \textbf{echo "questa è una prova" | tee esercizio.txt} $ $ \\ $
# torno nella mia home prima con il comando $ \textbf{cd} $ e poi attraverso $ \textbf{pwd} $

# %% [markdown]
# ![pippppo.png](attachment:0c1e005b-0e9f-455f-b810-564425f93ddc.png)

# %% [markdown]
# ## ESERCIZIO 4

# %% [markdown]
# Creato cartella tmp nella bash2. Creato file prova.txt attraverso $ \textbf{touch prova.txt} $ ed inserito la stringa attraverso $ \textbf{echo "*" > prova.txt} $

# %% [markdown]
# Copio il file prova.txt nel file beckup.txt attraverso il comando $ \textbf{cp prova.txt beckup.txt} $

# %% [markdown]
# ![viva.png](attachment:c8f2cd7d-b32b-4c3c-a662-02e4dd5e0126.png)

# %% [markdown]
# $ \textbf{ls} $ è il comando di "listing", ovvero mi fa una lista degli elementi che ho dentro una directory. $ \\ $
# $ \textbf{echo} $ è il comando di "eco", ovvero mi fa l'eco sulla console di quello che gli dico di fare. $ \\ $
# $ \textbf{cat} $ è il comando che mi permette di vedere cosa è contenuto all'interno di un file

# %% [markdown]
# ![ddd.png](attachment:88ddc9a9-ea2a-4629-84c4-ab954b693b5c.png)

# %% [markdown]
# quando scrivo $ \textbf{mv prova.txt copiaB.txt} $ sto dicendo al computer di rinominare il file prova.txt nel file copiaB.txt $ \\ $
# quando scrivo $ \textbf{cp prova.txt copiaB.txt} $ sto dicendo al computer di eseguire una copia del file prova.txt battezzata copiaB.txt $ \\ $
# qando scrivo $ \textbf{rm prova.txt} $ sto dicendo al computer di rimuovere il file prova.txt

# %% [markdown]
# Creo 10 file attraverso $ \textbf{touch prova0.txt, touch prova1.txt, ..., touch prova9.txt} $. Verifico se sono presenti $ \textbf{ls} $ e poi li rimuovo tutti con un singolo comando
# $ \textbf{rm prova0.txt prova1.txt ... prova9.txt} $

# %% [markdown]
# ![funki.png](attachment:e310ee4c-e77c-41d6-beba-2f082e7834d5.png)
